# %% [markdown]
# # Problem Statement: Movie Award Prediction: Given a details of movies we have to predict Movie will Award or not

# %% [markdown]
# we have to predict the movie will win award or not based on the previous data. Compare the result using logistic regression and naive bayes.

# %% [markdown]
# # Data Science Flow

# %%
1. Business Understanding (Project Name)----> (Domain Knowledge)-->Domain Expert

2. Data Requirement (What data is required to complete the project)

3. Data Collection (From Different sources and with Different Tools and Technologies)

4. Data Preparation (EDA/Data Preparation/Data Cleaning/Data Munging)

5. Machine Learning/Predictive Analysis /Data Modelling/Data Mining ( Clean Data + Algorithms= Model)
Generalised Model= Which work well in unseen Data

6. Model Evaluation -Evaluation metrics (Test Model)

7. Model Tuning

8. Model Deployment

9. Monitoring

# %% [markdown]
# # EDA of Movie Award prediction

# %%
EDA/ Data Preparation/Data Cleaning Steps

1. Removing Duplicate data

2. Missing Value Treatment

     6 Methods

3. Outlier Treatment

     5 Methods

4. Categorical to Numerical Conversion

5. Numerical to Categorical Conversion(Binning)

6. Feature Scaling

7. Feature Transformation

8. Feature selection

# %%
1. Import Libraries

2. Reading Dataset

3. Data Preprartion

4. Data Visulaization

Clean Data (Input and output )

5. Split the Data into Training and Testing

6. Apply algorithm Training Data

7. Predict on test Data 

8. Model Evaluation

# %% [markdown]
# # 1. Import Necessary Libraries

# %%
# Importing all necessary Libaries: Data Science Packages

import numpy as np # numpy used for mathematical operation on array
import pandas as pd  # pandas used for data manipulation on dataframe
import seaborn as sns # seaborn used for data visualization
import matplotlib.pyplot as plt # matplotlib used for data visualization

# %% [markdown]
# # 2. Reading Dataset

# %%
# Read the data with pandas

df = pd.read_csv("Movie_classification.csv", header=0)
df
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0              20.1264               59.62               0.462  36524.125
# 1              20.5462               69.14               0.531  35668.655
# 2              20.5458               69.14               0.531  39912.675
# 3              20.6474               59.36               0.542  38873.890
# 4              21.3810               59.36               0.542  39701.585
# ..                 ...                 ...                 ...        ...
# 501            21.2526               78.86               0.427  36624.115
# 502            20.9054               78.86               0.427  33996.600
# 503            21.2152               78.86               0.427  38751.680
# 504            22.1918               78.86               0.427  37740.670
# 505            20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0           138.7               7.825                8.095            7.910
# 1           152.4               7.505                7.650            7.440
# 2           134.6               7.485                7.570            7.495
# 3           119.3               6.895                7.035            6.920
# 4           127.7               6.920                7.070            6.815
# ..            ...                 ...                  ...              ...
# 501         142.6               8.680                8.775            8.620
# 502         150.2               8.780                8.945            8.770
# 503         164.5               8.830                8.970            8.855
# 504         162.8               8.730                8.845            8.800
# 505         154.3               8.640                8.880            8.680
#
#      Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# 0              7.995           7.94         527367          YES      109.60
# 1              7.470           7.44         494055           NO      146.64
# 2              7.515           7.44         547051           NO      147.88
# 3              7.020           8.26         516279          YES      185.36
# 4              7.070           8.26         531448           NO      176.48
# ..               ...            ...            ...          ...         ...
# 501            8.970           6.80         492480           NO      186.96
# 502            8.930           7.80         482875          YES      132.24
# 503            9.010           7.80         532239           NO      109.56
# 504            8.845           6.80         496077          YES      158.80
# 505            8.790           6.80         518438          YES      205.60
#
#      Twitter_hastags     Genre  Avg_age_actors  Num_multiplex  Collection  \
# 0            223.840  Thriller              23            494       48000
# 1            243.456     Drama              42            462       43200
# 2           2022.400    Comedy              38            458       69400
# 3            225.344     Drama              45            472       66800
# 4            225.792     Drama              55            395       72400
# ..               ...       ...             ...            ...         ...
# 501          243.584    Action              27            561       44800
# 502          263.296    Action              20            600       41200
# 503          243.824    Comedy              31            576       47800
# 504          303.520    Comedy              47            607       44000
# 505          203.040    Comedy              45            604       38000
#
#      Tech_Oscar
# 0             1
# 1             0
# 2             1
# 3             1
# 4             1
# ..          ...
# 501           0
# 502           0
# 503           0
# 504           0
# 505           0
#
# [506 rows x 19 columns]

# %%
# Reading first 5 Rows of the data

df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# 0            7.995           7.94         527367          YES      109.60
# 1            7.470           7.44         494055           NO      146.64
# 2            7.515           7.44         547051           NO      147.88
# 3            7.020           8.26         516279          YES      185.36
# 4            7.070           8.26         531448           NO      176.48
#
#    Twitter_hastags     Genre  Avg_age_actors  Num_multiplex  Collection  \
# 0          223.840  Thriller              23            494       48000
# 1          243.456     Drama              42            462       43200
# 2         2022.400    Comedy              38            458       69400
# 3          225.344     Drama              45            472       66800
# 4          225.792     Drama              55            395       72400
#
#    Tech_Oscar
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1

# %%
# Reading last 5 Rows of the data

df.tail()
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 501            21.2526               78.86               0.427  36624.115
# 502            20.9054               78.86               0.427  33996.600
# 503            21.2152               78.86               0.427  38751.680
# 504            22.1918               78.86               0.427  37740.670
# 505            20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 501         142.6                8.68                8.775            8.620
# 502         150.2                8.78                8.945            8.770
# 503         164.5                8.83                8.970            8.855
# 504         162.8                8.73                8.845            8.800
# 505         154.3                8.64                8.880            8.680
#
#      Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# 501            8.970            6.8         492480           NO      186.96
# 502            8.930            7.8         482875          YES      132.24
# 503            9.010            7.8         532239           NO      109.56
# 504            8.845            6.8         496077          YES      158.80
# 505            8.790            6.8         518438          YES      205.60
#
#      Twitter_hastags   Genre  Avg_age_actors  Num_multiplex  Collection  \
# 501          243.584  Action              27            561       44800
# 502          263.296  Action              20            600       41200
# 503          243.824  Comedy              31            576       47800
# 504          303.520  Comedy              47            607       44000
# 505          203.040  Comedy              45            604       38000
#
#      Tech_Oscar
# 501           0
# 502           0
# 503           0
# 504           0
# 505           0

# %%
# Reading last 5 Rows of the data

df.sample()
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 327            24.8206               69.76               0.507  33791.065
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 327         117.2               7.205                 7.31             7.26
#
#      Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# 327            7.395           8.08         448684           NO      180.88
#
#      Twitter_hastags   Genre  Avg_age_actors  Num_multiplex  Collection  \
# 327          303.552  Comedy              27            509       44400
#
#      Tech_Oscar
# 327           1

# %%
# Reading random 5 Rows of the data

df.sample(5)
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 485            93.4734               91.20               0.417  35063.160
# 338            20.6612               65.38               0.485  33657.745
# 173            21.8356               63.10               0.490  35640.880
# 287            20.7742               65.64               0.595  34490.995
# 169            68.9906               94.16               0.395  35563.110
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 485         125.4               7.985                8.075            7.965
# 338         110.8               7.545                7.740            7.465
# 173         157.6               8.570                8.715            8.615
# 287         104.8               6.275                6.400            6.210
# 169         168.7               8.850                8.940            8.835
#
#      Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# 485            7.995           7.96         465487           NO      180.48
# 338            7.625           7.96         466294          YES      162.24
# 173            8.805           7.68         467457          YES      197.44
# 287            6.475           7.68         514434          YES      199.28
# 169            8.850           8.06         449755           NO      110.92
#
#      Twitter_hastags     Genre  Avg_age_actors  Num_multiplex  Collection  \
# 485          263.392    Action              51            500       42400
# 338          283.296  Thriller              26            535       41200
# 173          203.776    Comedy              59            540       47200
# 287          283.712     Drama              60            433       46400
# 169          303.568    Action              22            536       44600
#
#      Tech_Oscar
# 485           1
# 338           1
# 173           0
# 287           0
# 169           0

# %%
# Checking the shape of the data

df.shape
# Out:
# (506, 19)

# %%
# Checking the rows of the data

df.shape[0]
# Out:
# 506

# %%
# Checking the column of the data

df.shape[1]
# Out:
# 19

# %%
#Reading the name of the columns

df.columns
# Out:
# Index(['Marketing expense', 'Production expense', 'Multiplex coverage',
#        'Budget', 'Movie_length', 'Lead_ Actor_Rating', 'Lead_Actress_rating',
#        'Director_rating', 'Producer_rating', 'Critic_rating', 'Trailer_views',
#        '3D_available', 'Time_taken', 'Twitter_hastags', 'Genre',
#        'Avg_age_actors', 'Num_multiplex', 'Collection', 'Tech_Oscar'],
#       dtype='object')

# %%
df.rename(columns={'Genre':'Genre_imp'})
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0              20.1264               59.62               0.462  36524.125
# 1              20.5462               69.14               0.531  35668.655
# 2              20.5458               69.14               0.531  39912.675
# 3              20.6474               59.36               0.542  38873.890
# 4              21.3810               59.36               0.542  39701.585
# ..                 ...                 ...                 ...        ...
# 501            21.2526               78.86               0.427  36624.115
# 502            20.9054               78.86               0.427  33996.600
# 503            21.2152               78.86               0.427  38751.680
# 504            22.1918               78.86               0.427  37740.670
# 505            20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0           138.7               7.825                8.095            7.910
# 1           152.4               7.505                7.650            7.440
# 2           134.6               7.485                7.570            7.495
# 3           119.3               6.895                7.035            6.920
# 4           127.7               6.920                7.070            6.815
# ..            ...                 ...                  ...              ...
# 501         142.6               8.680                8.775            8.620
# 502         150.2               8.780                8.945            8.770
# 503         164.5               8.830                8.970            8.855
# 504         162.8               8.730                8.845            8.800
# 505         154.3               8.640                8.880            8.680
#
#      Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# 0              7.995           7.94         527367          YES      109.60
# 1              7.470           7.44         494055           NO      146.64
# 2              7.515           7.44         547051           NO      147.88
# 3              7.020           8.26         516279          YES      185.36
# 4              7.070           8.26         531448           NO      176.48
# ..               ...            ...            ...          ...         ...
# 501            8.970           6.80         492480           NO      186.96
# 502            8.930           7.80         482875          YES      132.24
# 503            9.010           7.80         532239           NO      109.56
# 504            8.845           6.80         496077          YES      158.80
# 505            8.790           6.80         518438          YES      205.60
#
#      Twitter_hastags Genre_imp  Avg_age_actors  Num_multiplex  Collection  \
# 0            223.840  Thriller              23            494       48000
# 1            243.456     Drama              42            462       43200
# 2           2022.400    Comedy              38            458       69400
# 3            225.344     Drama              45            472       66800
# 4            225.792     Drama              55            395       72400
# ..               ...       ...             ...            ...         ...
# 501          243.584    Action              27            561       44800
# 502          263.296    Action              20            600       41200
# 503          243.824    Comedy              31            576       47800
# 504          303.520    Comedy              47            607       44000
# 505          203.040    Comedy              45            604       38000
#
#      Tech_Oscar
# 0             1
# 1             0
# 2             1
# 3             1
# 4             1
# ..          ...
# 501           0
# 502           0
# 503           0
# 504           0
# 505           0
#
# [506 rows x 19 columns]

# %%
df.dtypes
# Out:
# Marketing expense      float64
# Production expense     float64
# Multiplex coverage     float64
# Budget                 float64
# Movie_length           float64
# Lead_ Actor_Rating     float64
# Lead_Actress_rating    float64
# Director_rating        float64
# Producer_rating        float64
# Critic_rating          float64
# Trailer_views            int64
# 3D_available            object
# Time_taken             float64
# Twitter_hastags        float64
# Genre                   object
# Avg_age_actors           int64
# Num_multiplex            int64
# Collection               int64
# Tech_Oscar               int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           494 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
#  15  Avg_age_actors       506 non-null    int64
#  16  Num_multiplex        506 non-null    int64
#  17  Collection           506 non-null    int64
#  18  Tech_Oscar           506 non-null    int64
# dtypes: float64(12), int64(5), object(2)
# memory usage: 75.2+ KB

# %%
df.isnull()
# Out:
#      Marketing expense  Production expense  Multiplex coverage  Budget  \
# 0                False               False               False   False
# 1                False               False               False   False
# 2                False               False               False   False
# 3                False               False               False   False
# 4                False               False               False   False
# ..                 ...                 ...                 ...     ...
# 501              False               False               False   False
# 502              False               False               False   False
# 503              False               False               False   False
# 504              False               False               False   False
# 505              False               False               False   False
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0           False               False                False            False
# 1           False               False                False            False
# 2           False               False                False            False
# 3           False               False                False            False
# 4           False               False                False            False
# ..            ...                 ...                  ...              ...
# 501         False               False                False            False
# 502         False               False                False            False
# 503         False               False                False            False
# 504         False               False                False            False
# 505         False               False                False            False
#
#      Producer_rating  Critic_rating  Trailer_views  3D_available  Time_taken  \
# 0              False          False          False         False       False
# 1              False          False          False         False       False
# 2              False          False          False         False       False
# 3              False          False          False         False       False
# 4              False          False          False         False       False
# ..               ...            ...            ...           ...         ...
# 501            False          False          False         False       False
# 502            False          False          False         False       False
# 503            False          False          False         False       False
# 504            False          False          False         False       False
# 505            False          False          False         False       False
#
#      Twitter_hastags  Genre  Avg_age_actors  Num_multiplex  Collection  \
# 0              False  False           False          False       False
# 1              False  False           False          False       False
# 2              False  False           False          False       False
# 3              False  False           False          False       False
# 4              False  False           False          False       False
# ..               ...    ...             ...            ...         ...
# 501            False  False           False          False       False
# 502            False  False           False          False       False
# 503            False  False           False          False       False
# 504            False  False           False          False       False
# 505            False  False           False          False       False
#
#      Tech_Oscar
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# 501       False
# 502       False
# 503       False
# 504       False
# 505       False
#
# [506 rows x 19 columns]

# %%
df.isnull().sum()
# Out:
# Marketing expense       0
# Production expense      0
# Multiplex coverage      0
# Budget                  0
# Movie_length            0
# Lead_ Actor_Rating      0
# Lead_Actress_rating     0
# Director_rating         0
# Producer_rating         0
# Critic_rating           0
# Trailer_views           0
# 3D_available            0
# Time_taken             12
# Twitter_hastags         0
# Genre                   0
# Avg_age_actors          0
# Num_multiplex           0
# Collection              0
# Tech_Oscar              0
# dtype: int64

# %%
df.Budget
# Out:
# 0      36524.125
# 1      35668.655
# 2      39912.675
# 3      38873.890
# 4      39701.585
#          ...
# 501    36624.115
# 502    33996.600
# 503    38751.680
# 504    37740.670
# 505    33496.650
# Name: Budget, Length: 506, dtype: float64

# %%
df["Budget"]
# Out:
# 0      36524.125
# 1      35668.655
# 2      39912.675
# 3      38873.890
# 4      39701.585
#          ...
# 501    36624.115
# 502    33996.600
# 503    38751.680
# 504    37740.670
# 505    33496.650
# Name: Budget, Length: 506, dtype: float64

# %%
df.Genre
# Out:
# 0      Thriller
# 1         Drama
# 2        Comedy
# 3         Drama
# 4         Drama
#          ...
# 501      Action
# 502      Action
# 503      Comedy
# 504      Comedy
# 505      Comedy
# Name: Genre, Length: 506, dtype: object

# %%
plt.scatter(df['Marketing expense'],df['Production expense'])

# %%
# Creating the Data Dictionary with first column being datatype.

Data_dict = pd.DataFrame(df.dtypes)
Data_dict
# Out:
#                            0
# Marketing expense    float64
# Production expense   float64
# Multiplex coverage   float64
# Budget               float64
# Movie_length         float64
# Lead_ Actor_Rating   float64
# Lead_Actress_rating  float64
# Director_rating      float64
# Producer_rating      float64
# Critic_rating        float64
# Trailer_views          int64
# 3D_available          object
# Time_taken           float64
# Twitter_hastags      float64
# Genre                 object
# Avg_age_actors         int64
# Num_multiplex          int64
# Collection             int64
# Tech_Oscar             int64

# %%
# identifying the missing values from the dataset.

Data_dict['MissingVal'] = df.isnull().sum()
Data_dict
# Out:
#                            0  MissingVal
# Marketing expense    float64           0
# Production expense   float64           0
# Multiplex coverage   float64           0
# Budget               float64           0
# Movie_length         float64           0
# Lead_ Actor_Rating   float64           0
# Lead_Actress_rating  float64           0
# Director_rating      float64           0
# Producer_rating      float64           0
# Critic_rating        float64           0
# Trailer_views          int64           0
# 3D_available          object           0
# Time_taken           float64          12
# Twitter_hastags      float64           0
# Genre                 object           0
# Avg_age_actors         int64           0
# Num_multiplex          int64           0
# Collection             int64           0
# Tech_Oscar             int64           0

# %%
# Identifying unique values . For this we used nunique() which returns unique elements in the object.

df.nunique()
# Out:
# Marketing expense      504
# Production expense      76
# Multiplex coverage      81
# Budget                 446
# Movie_length           356
# Lead_ Actor_Rating     339
# Lead_Actress_rating    354
# Director_rating        339
# Producer_rating        353
# Critic_rating           74
# Trailer_views          504
# 3D_available             2
# Time_taken             449
# Twitter_hastags        423
# Genre                    4
# Avg_age_actors          42
# Num_multiplex          293
# Collection             228
# Tech_Oscar               2
# dtype: int64

# %%
# identifying count of the variable.

Data_dict['Count'] = df.count()
Data_dict
# Out:
#                            0  MissingVal  Count
# Marketing expense    float64           0    506
# Production expense   float64           0    506
# Multiplex coverage   float64           0    506
# Budget               float64           0    506
# Movie_length         float64           0    506
# Lead_ Actor_Rating   float64           0    506
# Lead_Actress_rating  float64           0    506
# Director_rating      float64           0    506
# Producer_rating      float64           0    506
# Critic_rating        float64           0    506
# Trailer_views          int64           0    506
# 3D_available          object           0    506
# Time_taken           float64          12    494
# Twitter_hastags      float64           0    506
# Genre                 object           0    506
# Avg_age_actors         int64           0    506
# Num_multiplex          int64           0    506
# Collection             int64           0    506
# Tech_Oscar             int64           0    506

# %% [markdown]
# # Discriptive Statistics

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# 0            7.995           7.94         527367          YES      109.60
# 1            7.470           7.44         494055           NO      146.64
# 2            7.515           7.44         547051           NO      147.88
# 3            7.020           8.26         516279          YES      185.36
# 4            7.070           8.26         531448           NO      176.48
#
#    Twitter_hastags     Genre  Avg_age_actors  Num_multiplex  Collection  \
# 0          223.840  Thriller              23            494       48000
# 1          243.456     Drama              42            462       43200
# 2         2022.400    Comedy              38            458       69400
# 3          225.344     Drama              45            472       66800
# 4          225.792     Drama              55            395       72400
#
#    Tech_Oscar
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1

# %%
sns.countplot(x ='Tech_Oscar', hue = "3D_available", data = df)
# Out:
# <AxesSubplot:xlabel='Tech_Oscar', ylabel='count'>

# %% [markdown]
# 3-D movies are winning more oscars

# %%
sns.countplot(x ='Tech_Oscar', hue = "Genre", data = df)
# Out:
# <AxesSubplot:xlabel='Tech_Oscar', ylabel='count'>

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# 0            7.995           7.94         527367          YES      109.60
# 1            7.470           7.44         494055           NO      146.64
# 2            7.515           7.44         547051           NO      147.88
# 3            7.020           8.26         516279          YES      185.36
# 4            7.070           8.26         531448           NO      176.48
#
#    Twitter_hastags     Genre  Avg_age_actors  Num_multiplex  Collection  \
# 0          223.840  Thriller              23            494       48000
# 1          243.456     Drama              42            462       43200
# 2         2022.400    Comedy              38            458       69400
# 3          225.344     Drama              45            472       66800
# 4          225.792     Drama              55            395       72400
#
#    Tech_Oscar
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1

# %%
# view the descriptive statistics of the dataset

df.describe()
# Out:
#        Marketing expense  Production expense  Multiplex coverage  \
# count         506.000000          506.000000          506.000000
# mean           92.270471           77.273557            0.445305
# std           172.030902           13.720706            0.115878
# min            20.126400           55.920000            0.129000
# 25%            21.640900           65.380000            0.376000
# 50%            25.130200           74.380000            0.462000
# 75%            93.541650           91.200000            0.551000
# max          1799.524000          110.480000            0.615000
#
#              Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# count    506.000000    506.000000          506.000000           506.000000
# mean   34911.144022    142.074901            8.014002             8.185613
# std     3903.038232     28.148861            1.054266             1.054290
# min    19781.355000     76.400000            3.840000             4.035000
# 25%    32693.952500    118.525000            7.316250             7.503750
# 50%    34488.217500    151.000000            8.307500             8.495000
# 75%    36793.542500    167.575000            8.865000             9.030000
# max    48772.900000    173.500000            9.435000             9.540000
#
#        Director_rating  Producer_rating  Critic_rating  Trailer_views  \
# count       506.000000       506.000000     506.000000     506.000000
# mean          8.019664         8.190514       7.810870  449860.715415
# std           1.059899         1.049601       0.659699   68917.763145
# min           3.840000         4.030000       6.600000  212912.000000
# 25%           7.296250         7.507500       7.200000  409128.000000
# 50%           8.312500         8.465000       7.960000  462460.000000
# 75%           8.883750         9.030000       8.260000  500247.500000
# max           9.425000         9.635000       9.400000  567784.000000
#
#        Time_taken  Twitter_hastags  Avg_age_actors  Num_multiplex  \
# count  494.000000       506.000000      506.000000     506.000000
# mean   157.391498       260.832095       39.181818     545.043478
# std     31.295161       104.779133       12.513697     106.332889
# min      0.000000       201.152000        3.000000     333.000000
# 25%    132.300000       223.796000       28.000000     465.000000
# 50%    160.000000       254.400000       39.000000     535.500000
# 75%    181.890000       283.416000       50.000000     614.750000
# max    217.520000      2022.400000       60.000000     868.000000
#
#           Collection  Tech_Oscar
# count     506.000000  506.000000
# mean    45057.707510    0.545455
# std     18364.351764    0.498422
# min     10000.000000    0.000000
# 25%     34050.000000    0.000000
# 50%     42400.000000    1.000000
# 75%     50000.000000    1.000000
# max    100000.000000    1.000000

# %%
plt.hist(df['Marketing expense'])
# Out:
# (array([439.,  44.,  14.,   1.,   3.,   2.,   0.,   1.,   1.,   1.]),
#  array([  20.1264 ,  198.06616,  376.00592,  553.94568,  731.88544,
#          909.8252 , 1087.76496, 1265.70472, 1443.64448, 1621.58424,
#         1799.524  ]),
#  <BarContainer object of 10 artists>)

# %%
df.median()
# Out:
# C:\Users\ankit\AppData\Local\Temp/ipykernel_764/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Marketing expense          25.1302
# Production expense         74.3800
# Multiplex coverage          0.4620
# Budget                  34488.2175
# Movie_length              151.0000
# Lead_ Actor_Rating          8.3075
# Lead_Actress_rating         8.4950
# Director_rating             8.3125
# Producer_rating             8.4650
# Critic_rating               7.9600
# Trailer_views          462460.0000
# Time_taken                160.0000
# Twitter_hastags           254.4000
# Avg_age_actors             39.0000
# Num_multiplex             535.5000
# Collection              42400.0000
# Tech_Oscar                  1.0000
# dtype: float64

# %%
plt.hist(df['Time_taken'])
# Out:
# (array([  2.,   0.,   0.,   0.,   7., 108., 101., 106., 110.,  60.]),
#  array([  0.   ,  21.752,  43.504,  65.256,  87.008, 108.76 , 130.512,
#         152.264, 174.016, 195.768, 217.52 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Missing Value Imputation

# %%
# calculating the mean of the Time_taken 

df['Time_taken'].median()
# Out:
# 160.0

# %%
# calculating the mean of the Time_taken  and replace the missing value with mean

df['Time_taken'].fillna(value = df['Time_taken'].median(), inplace = True)

# %%
# View info of Columns of the dataset such as number of entries, name of columns and data type


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           506 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
#  15  Avg_age_actors       506 non-null    int64
#  16  Num_multiplex        506 non-null    int64
#  17  Collection           506 non-null    int64
#  18  Tech_Oscar           506 non-null    int64
# dtypes: float64(12), int64(5), object(2)
# memory usage: 75.2+ KB

# %%
# checking the null values column wise

df.isnull().sum()
# Out:
# Marketing expense      0
# Production expense     0
# Multiplex coverage     0
# Budget                 0
# Movie_length           0
# Lead_ Actor_Rating     0
# Lead_Actress_rating    0
# Director_rating        0
# Producer_rating        0
# Critic_rating          0
# Trailer_views          0
# 3D_available           0
# Time_taken             0
# Twitter_hastags        0
# Genre                  0
# Avg_age_actors         0
# Num_multiplex          0
# Collection             0
# Tech_Oscar             0
# dtype: int64

# %%
#Checking the null values of complete dataset

df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Dummy Variable Creation

# %%
# checking the first five rows of the dataset

df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# 0            7.995           7.94         527367          YES      109.60
# 1            7.470           7.44         494055           NO      146.64
# 2            7.515           7.44         547051           NO      147.88
# 3            7.020           8.26         516279          YES      185.36
# 4            7.070           8.26         531448           NO      176.48
#
#    Twitter_hastags     Genre  Avg_age_actors  Num_multiplex  Collection  \
# 0          223.840  Thriller              23            494       48000
# 1          243.456     Drama              42            462       43200
# 2         2022.400    Comedy              38            458       69400
# 3          225.344     Drama              45            472       66800
# 4          225.792     Drama              55            395       72400
#
#    Tech_Oscar
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1

# %%
# Converting non numerical column into numerical usin get dummies method

df = pd.get_dummies(df,columns = ["3D_available","Genre"],drop_first = True)

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  ...  Time_taken  Twitter_hastags  \
# 0            7.995           7.94  ...      109.60          223.840
# 1            7.470           7.44  ...      146.64          243.456
# 2            7.515           7.44  ...      147.88         2022.400
# 3            7.020           8.26  ...      185.36          225.344
# 4            7.070           8.26  ...      176.48          225.792
#
#    Avg_age_actors  Num_multiplex  Collection  Tech_Oscar  3D_available_YES  \
# 0              23            494       48000           1                 1
# 1              42            462       43200           0                 0
# 2              38            458       69400           1                 0
# 3              45            472       66800           1                 1
# 4              55            395       72400           1                 0
#
#    Genre_Comedy  Genre_Drama  Genre_Thriller
# 0             0            0               1
# 1             0            1               0
# 2             1            0               0
# 3             0            1               0
# 4             0            1               0
#
# [5 rows x 21 columns]

# %%
import scipy.stats as stats
for col in df:
    print(col)
    print(df[col].skew())
    sns.distplot(df[col])
    plt.show()
    stats.probplot(df[col], dist= "norm", plot=plt)
    plt.show()
# Out:
# Marketing expense
# 5.223148798243854
# C:\Users\ankit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Production expense
# 0.29502156787351164
# C:\Users\ankit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Multiplex coverage
# -0.7293079225348803
# C:\Users\ankit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Budget
# 0.4036121332887459
# C:\Users\ankit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Movie_length
# -0.5989626398812932
# C:\Users\ankit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Lead_ Actor_Rating
# -1.0105771419232832
# C:\Users\ankit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Lead_Actress_rating
# -1.0074915678516585
# C:\Users\ankit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Director_rating
# -1.003848463506819
# C:\Users\ankit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Producer_rating
# -1.0046803326874403
# C:\Users\ankit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Critic_rating
# 0.17613874584541747
# C:\Users\ankit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Trailer_views
# -0.8438305191616551
# C:\Users\ankit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Time_taken
# -0.4850546359953343
# C:\Users\ankit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Twitter_hastags
# 13.790551744611685
# C:\Users\ankit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Avg_age_actors
# 0.012970775572580903
# C:\Users\ankit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Num_multiplex
# 0.5342214102668082
# C:\Users\ankit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Collection
# 1.1109118502479602
# C:\Users\ankit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Tech_Oscar
# -0.1831174718108712
# C:\Users\ankit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 3D_available_YES
# -0.2072424531507983
# C:\Users\ankit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Genre_Comedy
# 0.842804944975038
# C:\Users\ankit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Genre_Drama
# 1.5710770476142906
# C:\Users\ankit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Genre_Thriller
# 0.5775527295278238
# C:\Users\ankit\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# checking the number of rows and columns after converting complete dataset into numerical

df.shape
# Out:
# (506, 21)

# %% [markdown]
# ### Data Visualization

# %%
# calculating the correlation of complete dataset

corr = df.corr()
corr
# Out:
#                      Marketing expense  Production expense  \
# Marketing expense             1.000000            0.406583
# Production expense            0.406583            1.000000
# Multiplex coverage           -0.420972           -0.763651
# Budget                       -0.219247           -0.391676
# Movie_length                  0.352734            0.644779
# Lead_ Actor_Rating            0.380050            0.706481
# Lead_Actress_rating           0.379813            0.707956
# Director_rating               0.380069            0.707566
# Producer_rating               0.376462            0.705819
# Critic_rating                -0.184985           -0.251565
# Trailer_views                -0.443457           -0.591657
# Time_taken                    0.026108            0.015736
# Twitter_hastags               0.013518           -0.000839
# Avg_age_actors                0.059204            0.055810
# Num_multiplex                 0.383298            0.707559
# Collection                   -0.389582           -0.484754
# Tech_Oscar                   -0.013417           -0.024404
# 3D_available_YES             -0.086805           -0.115401
# Genre_Comedy                  0.066796            0.086958
# Genre_Drama                  -0.016894           -0.026590
# Genre_Thriller               -0.037123           -0.098976
#
#                      Multiplex coverage    Budget  Movie_length  \
# Marketing expense             -0.420972 -0.219247      0.352734
# Production expense            -0.763651 -0.391676      0.644779
# Multiplex coverage             1.000000  0.302188     -0.731470
# Budget                         0.302188  1.000000     -0.240265
# Movie_length                  -0.731470 -0.240265      1.000000
# Lead_ Actor_Rating            -0.768589 -0.208464      0.746904
# Lead_Actress_rating           -0.769724 -0.203981      0.746493
# Director_rating               -0.769157 -0.201907      0.747021
# Producer_rating               -0.764873 -0.205397      0.746707
# Critic_rating                  0.145555  0.232361     -0.217830
# Trailer_views                  0.581386  0.602536     -0.589318
# Time_taken                     0.034891  0.039697     -0.019136
# Twitter_hastags                0.004882  0.030674      0.009380
# Avg_age_actors                -0.092104 -0.064694      0.075198
# Num_multiplex                 -0.915495 -0.282796      0.673896
# Collection                     0.429300  0.696304     -0.377999
# Tech_Oscar                    -0.004017 -0.027148      0.016291
# 3D_available_YES               0.073903  0.163774      0.005101
# Genre_Comedy                  -0.068554 -0.052579      0.092693
# Genre_Drama                    0.046393 -0.004195      0.003452
# Genre_Thriller                 0.037772  0.046251     -0.088609
#
#                      Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# Marketing expense              0.380050             0.379813         0.380069
# Production expense             0.706481             0.707956         0.707566
# Multiplex coverage            -0.768589            -0.769724        -0.769157
# Budget                        -0.208464            -0.203981        -0.201907
# Movie_length                   0.746904             0.746493         0.747021
# Lead_ Actor_Rating             1.000000             0.997905         0.997735
# Lead_Actress_rating            0.997905             1.000000         0.998097
# Director_rating                0.997735             0.998097         1.000000
# Producer_rating                0.994073             0.994003         0.994126
# Critic_rating                 -0.169978            -0.165992        -0.166638
# Trailer_views                 -0.490267            -0.487536        -0.486452
# Time_taken                     0.038524             0.038407         0.036293
# Twitter_hastags                0.014463             0.010239         0.010077
# Avg_age_actors                 0.036794             0.038005         0.041470
# Num_multiplex                  0.706331             0.708257         0.709364
# Collection                    -0.251355            -0.249459        -0.246650
# Tech_Oscar                    -0.035309            -0.040356        -0.035768
# 3D_available_YES              -0.025208            -0.020056        -0.020195
# Genre_Comedy                   0.044592             0.046974         0.046268
# Genre_Drama                   -0.035171            -0.038965        -0.033510
# Genre_Thriller                -0.030763            -0.030566        -0.033634
#
#                      Producer_rating  Critic_rating  ...  Time_taken  \
# Marketing expense           0.376462      -0.184985  ...    0.026108
# Production expense          0.705819      -0.251565  ...    0.015736
# Multiplex coverage         -0.764873       0.145555  ...    0.034891
# Budget                     -0.205397       0.232361  ...    0.039697
# Movie_length                0.746707      -0.217830  ...   -0.019136
# Lead_ Actor_Rating          0.994073      -0.169978  ...    0.038524
# Lead_Actress_rating         0.994003      -0.165992  ...    0.038407
# Director_rating             0.994126      -0.166638  ...    0.036293
# Producer_rating             1.000000      -0.167003  ...    0.029083
# Critic_rating              -0.167003       1.000000  ...   -0.015898
# Trailer_views              -0.487911       0.228641  ...    0.073589
# Time_taken                  0.029083      -0.015898  ...    1.000000
# Twitter_hastags             0.005850      -0.023655  ...   -0.006564
# Avg_age_actors              0.032542      -0.049797  ...    0.071200
# Num_multiplex               0.703518      -0.128769  ...   -0.056093
# Collection                 -0.248200       0.341288  ...    0.109128
# Tech_Oscar                 -0.043612      -0.001084  ...   -0.063930
# 3D_available_YES           -0.020022       0.039235  ...   -0.024301
# Genre_Comedy                0.051274      -0.015253  ...    0.013024
# Genre_Drama                -0.031696       0.057177  ...    0.049577
# Genre_Thriller             -0.033829      -0.037129  ...   -0.098248
#
#                      Twitter_hastags  Avg_age_actors  Num_multiplex  \
# Marketing expense           0.013518        0.059204       0.383298
# Production expense         -0.000839        0.055810       0.707559
# Multiplex coverage          0.004882       -0.092104      -0.915495
# Budget                      0.030674       -0.064694      -0.282796
# Movie_length                0.009380        0.075198       0.673896
# Lead_ Actor_Rating          0.014463        0.036794       0.706331
# Lead_Actress_rating         0.010239        0.038005       0.708257
# Director_rating             0.010077        0.041470       0.709364
# Producer_rating             0.005850        0.032542       0.703518
# Critic_rating              -0.023655       -0.049797      -0.128769
# Trailer_views              -0.006704       -0.049726      -0.544100
# Time_taken                 -0.006564        0.071200      -0.056093
# Twitter_hastags             1.000000       -0.004840       0.006255
# Avg_age_actors             -0.004840        1.000000       0.078811
# Num_multiplex               0.006255        0.078811       1.000000
# Collection                  0.023122       -0.047426      -0.391729
# Tech_Oscar                  0.077333        0.040581      -0.004857
# 3D_available_YES           -0.066012       -0.013581      -0.052262
# Genre_Comedy                0.034407       -0.030584       0.070720
# Genre_Drama                 0.036442       -0.015918      -0.035126
# Genre_Thriller             -0.058431       -0.036611      -0.048863
#
#                      Collection  Tech_Oscar  3D_available_YES  Genre_Comedy  \
# Marketing expense     -0.389582   -0.013417         -0.086805      0.066796
# Production expense    -0.484754   -0.024404         -0.115401      0.086958
# Multiplex coverage     0.429300   -0.004017          0.073903     -0.068554
# Budget                 0.696304   -0.027148          0.163774     -0.052579
# Movie_length          -0.377999    0.016291          0.005101      0.092693
# Lead_ Actor_Rating    -0.251355   -0.035309         -0.025208      0.044592
# Lead_Actress_rating   -0.249459   -0.040356         -0.020056      0.046974
# Director_rating       -0.246650   -0.035768         -0.020195      0.046268
# Producer_rating       -0.248200   -0.043612         -0.020022      0.051274
# Critic_rating          0.341288   -0.001084          0.039235     -0.015253
# Trailer_views          0.720119   -0.075783          0.090664     -0.106439
# Time_taken             0.109128   -0.063930         -0.024301      0.013024
# Twitter_hastags        0.023122    0.077333         -0.066012      0.034407
# Avg_age_actors        -0.047426    0.040581         -0.013581     -0.030584
# Num_multiplex         -0.391729   -0.004857         -0.052262      0.070720
# Collection             1.000000    0.154698          0.182867     -0.077478
# Tech_Oscar             0.154698    1.000000          0.070371      0.021134
# 3D_available_YES       0.182867    0.070371          1.000000      0.004617
# Genre_Comedy          -0.077478    0.021134          0.004617      1.000000
# Genre_Drama            0.036233    0.061414          0.035491     -0.323621
# Genre_Thriller         0.071751   -0.072842          0.017341     -0.500192
#
#                      Genre_Drama  Genre_Thriller
# Marketing expense      -0.016894       -0.037123
# Production expense     -0.026590       -0.098976
# Multiplex coverage      0.046393        0.037772
# Budget                 -0.004195        0.046251
# Movie_length            0.003452       -0.088609
# Lead_ Actor_Rating     -0.035171       -0.030763
# Lead_Actress_rating    -0.038965       -0.030566
# Director_rating        -0.033510       -0.033634
# Producer_rating        -0.031696       -0.033829
# Critic_rating           0.057177       -0.037129
# Trailer_views          -0.000179        0.109849
# Time_taken              0.049577       -0.098248
# Twitter_hastags         0.036442       -0.058431
# Avg_age_actors         -0.015918       -0.036611
# Num_multiplex          -0.035126       -0.048863
# Collection              0.036233        0.071751
# Tech_Oscar              0.061414       -0.072842
# 3D_available_YES        0.035491        0.017341
# Genre_Comedy           -0.323621       -0.500192
# Genre_Drama             1.000000       -0.366563
# Genre_Thriller         -0.366563        1.000000
#
# [21 rows x 21 columns]

# %%
# Visulaizing the heatmap of complete dataset

sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
df.drop('Multiplex coverage', axis=1,inplace=True)

# %%
corr = df.corr()
corr
# Out:
#                      Marketing expense  Production expense    Budget  \
# Marketing expense             1.000000            0.406583 -0.219247
# Production expense            0.406583            1.000000 -0.391676
# Budget                       -0.219247           -0.391676  1.000000
# Movie_length                  0.352734            0.644779 -0.240265
# Lead_ Actor_Rating            0.380050            0.706481 -0.208464
# Lead_Actress_rating           0.379813            0.707956 -0.203981
# Director_rating               0.380069            0.707566 -0.201907
# Producer_rating               0.376462            0.705819 -0.205397
# Critic_rating                -0.184985           -0.251565  0.232361
# Trailer_views                -0.443457           -0.591657  0.602536
# Time_taken                    0.026108            0.015736  0.039697
# Twitter_hastags               0.013518           -0.000839  0.030674
# Avg_age_actors                0.059204            0.055810 -0.064694
# Num_multiplex                 0.383298            0.707559 -0.282796
# Collection                   -0.389582           -0.484754  0.696304
# Tech_Oscar                   -0.013417           -0.024404 -0.027148
# 3D_available_YES             -0.086805           -0.115401  0.163774
# Genre_Comedy                  0.066796            0.086958 -0.052579
# Genre_Drama                  -0.016894           -0.026590 -0.004195
# Genre_Thriller               -0.037123           -0.098976  0.046251
#
#                      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# Marketing expense        0.352734            0.380050             0.379813
# Production expense       0.644779            0.706481             0.707956
# Budget                  -0.240265           -0.208464            -0.203981
# Movie_length             1.000000            0.746904             0.746493
# Lead_ Actor_Rating       0.746904            1.000000             0.997905
# Lead_Actress_rating      0.746493            0.997905             1.000000
# Director_rating          0.747021            0.997735             0.998097
# Producer_rating          0.746707            0.994073             0.994003
# Critic_rating           -0.217830           -0.169978            -0.165992
# Trailer_views           -0.589318           -0.490267            -0.487536
# Time_taken              -0.019136            0.038524             0.038407
# Twitter_hastags          0.009380            0.014463             0.010239
# Avg_age_actors           0.075198            0.036794             0.038005
# Num_multiplex            0.673896            0.706331             0.708257
# Collection              -0.377999           -0.251355            -0.249459
# Tech_Oscar               0.016291           -0.035309            -0.040356
# 3D_available_YES         0.005101           -0.025208            -0.020056
# Genre_Comedy             0.092693            0.044592             0.046974
# Genre_Drama              0.003452           -0.035171            -0.038965
# Genre_Thriller          -0.088609           -0.030763            -0.030566
#
#                      Director_rating  Producer_rating  Critic_rating  \
# Marketing expense           0.380069         0.376462      -0.184985
# Production expense          0.707566         0.705819      -0.251565
# Budget                     -0.201907        -0.205397       0.232361
# Movie_length                0.747021         0.746707      -0.217830
# Lead_ Actor_Rating          0.997735         0.994073      -0.169978
# Lead_Actress_rating         0.998097         0.994003      -0.165992
# Director_rating             1.000000         0.994126      -0.166638
# Producer_rating             0.994126         1.000000      -0.167003
# Critic_rating              -0.166638        -0.167003       1.000000
# Trailer_views              -0.486452        -0.487911       0.228641
# Time_taken                  0.036293         0.029083      -0.015898
# Twitter_hastags             0.010077         0.005850      -0.023655
# Avg_age_actors              0.041470         0.032542      -0.049797
# Num_multiplex               0.709364         0.703518      -0.128769
# Collection                 -0.246650        -0.248200       0.341288
# Tech_Oscar                 -0.035768        -0.043612      -0.001084
# 3D_available_YES           -0.020195        -0.020022       0.039235
# Genre_Comedy                0.046268         0.051274      -0.015253
# Genre_Drama                -0.033510        -0.031696       0.057177
# Genre_Thriller             -0.033634        -0.033829      -0.037129
#
#                      Trailer_views  Time_taken  Twitter_hastags  \
# Marketing expense        -0.443457    0.026108         0.013518
# Production expense       -0.591657    0.015736        -0.000839
# Budget                    0.602536    0.039697         0.030674
# Movie_length             -0.589318   -0.019136         0.009380
# Lead_ Actor_Rating       -0.490267    0.038524         0.014463
# Lead_Actress_rating      -0.487536    0.038407         0.010239
# Director_rating          -0.486452    0.036293         0.010077
# Producer_rating          -0.487911    0.029083         0.005850
# Critic_rating             0.228641   -0.015898        -0.023655
# Trailer_views             1.000000    0.073589        -0.006704
# Time_taken                0.073589    1.000000        -0.006564
# Twitter_hastags          -0.006704   -0.006564         1.000000
# Avg_age_actors           -0.049726    0.071200        -0.004840
# Num_multiplex            -0.544100   -0.056093         0.006255
# Collection                0.720119    0.109128         0.023122
# Tech_Oscar               -0.075783   -0.063930         0.077333
# 3D_available_YES          0.090664   -0.024301        -0.066012
# Genre_Comedy             -0.106439    0.013024         0.034407
# Genre_Drama              -0.000179    0.049577         0.036442
# Genre_Thriller            0.109849   -0.098248        -0.058431
#
#                      Avg_age_actors  Num_multiplex  Collection  Tech_Oscar  \
# Marketing expense          0.059204       0.383298   -0.389582   -0.013417
# Production expense         0.055810       0.707559   -0.484754   -0.024404
# Budget                    -0.064694      -0.282796    0.696304   -0.027148
# Movie_length               0.075198       0.673896   -0.377999    0.016291
# Lead_ Actor_Rating         0.036794       0.706331   -0.251355   -0.035309
# Lead_Actress_rating        0.038005       0.708257   -0.249459   -0.040356
# Director_rating            0.041470       0.709364   -0.246650   -0.035768
# Producer_rating            0.032542       0.703518   -0.248200   -0.043612
# Critic_rating             -0.049797      -0.128769    0.341288   -0.001084
# Trailer_views             -0.049726      -0.544100    0.720119   -0.075783
# Time_taken                 0.071200      -0.056093    0.109128   -0.063930
# Twitter_hastags           -0.004840       0.006255    0.023122    0.077333
# Avg_age_actors             1.000000       0.078811   -0.047426    0.040581
# Num_multiplex              0.078811       1.000000   -0.391729   -0.004857
# Collection                -0.047426      -0.391729    1.000000    0.154698
# Tech_Oscar                 0.040581      -0.004857    0.154698    1.000000
# 3D_available_YES          -0.013581      -0.052262    0.182867    0.070371
# Genre_Comedy              -0.030584       0.070720   -0.077478    0.021134
# Genre_Drama               -0.015918      -0.035126    0.036233    0.061414
# Genre_Thriller            -0.036611      -0.048863    0.071751   -0.072842
#
#                      3D_available_YES  Genre_Comedy  Genre_Drama  \
# Marketing expense           -0.086805      0.066796    -0.016894
# Production expense          -0.115401      0.086958    -0.026590
# Budget                       0.163774     -0.052579    -0.004195
# Movie_length                 0.005101      0.092693     0.003452
# Lead_ Actor_Rating          -0.025208      0.044592    -0.035171
# Lead_Actress_rating         -0.020056      0.046974    -0.038965
# Director_rating             -0.020195      0.046268    -0.033510
# Producer_rating             -0.020022      0.051274    -0.031696
# Critic_rating                0.039235     -0.015253     0.057177
# Trailer_views                0.090664     -0.106439    -0.000179
# Time_taken                  -0.024301      0.013024     0.049577
# Twitter_hastags             -0.066012      0.034407     0.036442
# Avg_age_actors              -0.013581     -0.030584    -0.015918
# Num_multiplex               -0.052262      0.070720    -0.035126
# Collection                   0.182867     -0.077478     0.036233
# Tech_Oscar                   0.070371      0.021134     0.061414
# 3D_available_YES             1.000000      0.004617     0.035491
# Genre_Comedy                 0.004617      1.000000    -0.323621
# Genre_Drama                  0.035491     -0.323621     1.000000
# Genre_Thriller               0.017341     -0.500192    -0.366563
#
#                      Genre_Thriller
# Marketing expense         -0.037123
# Production expense        -0.098976
# Budget                     0.046251
# Movie_length              -0.088609
# Lead_ Actor_Rating        -0.030763
# Lead_Actress_rating       -0.030566
# Director_rating           -0.033634
# Producer_rating           -0.033829
# Critic_rating             -0.037129
# Trailer_views              0.109849
# Time_taken                -0.098248
# Twitter_hastags           -0.058431
# Avg_age_actors            -0.036611
# Num_multiplex             -0.048863
# Collection                 0.071751
# Tech_Oscar                -0.072842
# 3D_available_YES           0.017341
# Genre_Comedy              -0.500192
# Genre_Drama               -0.366563
# Genre_Thriller             1.000000

# %%
df.drop('Num_multiplex', axis=1,inplace=True)

# %%
df.corr()
# Out:
#                      Marketing expense  Production expense    Budget  \
# Marketing expense             1.000000            0.406583 -0.219247
# Production expense            0.406583            1.000000 -0.391676
# Budget                       -0.219247           -0.391676  1.000000
# Movie_length                  0.352734            0.644779 -0.240265
# Lead_ Actor_Rating            0.380050            0.706481 -0.208464
# Lead_Actress_rating           0.379813            0.707956 -0.203981
# Director_rating               0.380069            0.707566 -0.201907
# Producer_rating               0.376462            0.705819 -0.205397
# Critic_rating                -0.184985           -0.251565  0.232361
# Trailer_views                -0.443457           -0.591657  0.602536
# Time_taken                    0.026108            0.015736  0.039697
# Twitter_hastags               0.013518           -0.000839  0.030674
# Avg_age_actors                0.059204            0.055810 -0.064694
# Collection                   -0.389582           -0.484754  0.696304
# Tech_Oscar                   -0.013417           -0.024404 -0.027148
# 3D_available_YES             -0.086805           -0.115401  0.163774
# Genre_Comedy                  0.066796            0.086958 -0.052579
# Genre_Drama                  -0.016894           -0.026590 -0.004195
# Genre_Thriller               -0.037123           -0.098976  0.046251
#
#                      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# Marketing expense        0.352734            0.380050             0.379813
# Production expense       0.644779            0.706481             0.707956
# Budget                  -0.240265           -0.208464            -0.203981
# Movie_length             1.000000            0.746904             0.746493
# Lead_ Actor_Rating       0.746904            1.000000             0.997905
# Lead_Actress_rating      0.746493            0.997905             1.000000
# Director_rating          0.747021            0.997735             0.998097
# Producer_rating          0.746707            0.994073             0.994003
# Critic_rating           -0.217830           -0.169978            -0.165992
# Trailer_views           -0.589318           -0.490267            -0.487536
# Time_taken              -0.019136            0.038524             0.038407
# Twitter_hastags          0.009380            0.014463             0.010239
# Avg_age_actors           0.075198            0.036794             0.038005
# Collection              -0.377999           -0.251355            -0.249459
# Tech_Oscar               0.016291           -0.035309            -0.040356
# 3D_available_YES         0.005101           -0.025208            -0.020056
# Genre_Comedy             0.092693            0.044592             0.046974
# Genre_Drama              0.003452           -0.035171            -0.038965
# Genre_Thriller          -0.088609           -0.030763            -0.030566
#
#                      Director_rating  Producer_rating  Critic_rating  \
# Marketing expense           0.380069         0.376462      -0.184985
# Production expense          0.707566         0.705819      -0.251565
# Budget                     -0.201907        -0.205397       0.232361
# Movie_length                0.747021         0.746707      -0.217830
# Lead_ Actor_Rating          0.997735         0.994073      -0.169978
# Lead_Actress_rating         0.998097         0.994003      -0.165992
# Director_rating             1.000000         0.994126      -0.166638
# Producer_rating             0.994126         1.000000      -0.167003
# Critic_rating              -0.166638        -0.167003       1.000000
# Trailer_views              -0.486452        -0.487911       0.228641
# Time_taken                  0.036293         0.029083      -0.015898
# Twitter_hastags             0.010077         0.005850      -0.023655
# Avg_age_actors              0.041470         0.032542      -0.049797
# Collection                 -0.246650        -0.248200       0.341288
# Tech_Oscar                 -0.035768        -0.043612      -0.001084
# 3D_available_YES           -0.020195        -0.020022       0.039235
# Genre_Comedy                0.046268         0.051274      -0.015253
# Genre_Drama                -0.033510        -0.031696       0.057177
# Genre_Thriller             -0.033634        -0.033829      -0.037129
#
#                      Trailer_views  Time_taken  Twitter_hastags  \
# Marketing expense        -0.443457    0.026108         0.013518
# Production expense       -0.591657    0.015736        -0.000839
# Budget                    0.602536    0.039697         0.030674
# Movie_length             -0.589318   -0.019136         0.009380
# Lead_ Actor_Rating       -0.490267    0.038524         0.014463
# Lead_Actress_rating      -0.487536    0.038407         0.010239
# Director_rating          -0.486452    0.036293         0.010077
# Producer_rating          -0.487911    0.029083         0.005850
# Critic_rating             0.228641   -0.015898        -0.023655
# Trailer_views             1.000000    0.073589        -0.006704
# Time_taken                0.073589    1.000000        -0.006564
# Twitter_hastags          -0.006704   -0.006564         1.000000
# Avg_age_actors           -0.049726    0.071200        -0.004840
# Collection                0.720119    0.109128         0.023122
# Tech_Oscar               -0.075783   -0.063930         0.077333
# 3D_available_YES          0.090664   -0.024301        -0.066012
# Genre_Comedy             -0.106439    0.013024         0.034407
# Genre_Drama              -0.000179    0.049577         0.036442
# Genre_Thriller            0.109849   -0.098248        -0.058431
#
#                      Avg_age_actors  Collection  Tech_Oscar  3D_available_YES  \
# Marketing expense          0.059204   -0.389582   -0.013417         -0.086805
# Production expense         0.055810   -0.484754   -0.024404         -0.115401
# Budget                    -0.064694    0.696304   -0.027148          0.163774
# Movie_length               0.075198   -0.377999    0.016291          0.005101
# Lead_ Actor_Rating         0.036794   -0.251355   -0.035309         -0.025208
# Lead_Actress_rating        0.038005   -0.249459   -0.040356         -0.020056
# Director_rating            0.041470   -0.246650   -0.035768         -0.020195
# Producer_rating            0.032542   -0.248200   -0.043612         -0.020022
# Critic_rating             -0.049797    0.341288   -0.001084          0.039235
# Trailer_views             -0.049726    0.720119   -0.075783          0.090664
# Time_taken                 0.071200    0.109128   -0.063930         -0.024301
# Twitter_hastags           -0.004840    0.023122    0.077333         -0.066012
# Avg_age_actors             1.000000   -0.047426    0.040581         -0.013581
# Collection                -0.047426    1.000000    0.154698          0.182867
# Tech_Oscar                 0.040581    0.154698    1.000000          0.070371
# 3D_available_YES          -0.013581    0.182867    0.070371          1.000000
# Genre_Comedy              -0.030584   -0.077478    0.021134          0.004617
# Genre_Drama               -0.015918    0.036233    0.061414          0.035491
# Genre_Thriller            -0.036611    0.071751   -0.072842          0.017341
#
#                      Genre_Comedy  Genre_Drama  Genre_Thriller
# Marketing expense        0.066796    -0.016894       -0.037123
# Production expense       0.086958    -0.026590       -0.098976
# Budget                  -0.052579    -0.004195        0.046251
# Movie_length             0.092693     0.003452       -0.088609
# Lead_ Actor_Rating       0.044592    -0.035171       -0.030763
# Lead_Actress_rating      0.046974    -0.038965       -0.030566
# Director_rating          0.046268    -0.033510       -0.033634
# Producer_rating          0.051274    -0.031696       -0.033829
# Critic_rating           -0.015253     0.057177       -0.037129
# Trailer_views           -0.106439    -0.000179        0.109849
# Time_taken               0.013024     0.049577       -0.098248
# Twitter_hastags          0.034407     0.036442       -0.058431
# Avg_age_actors          -0.030584    -0.015918       -0.036611
# Collection              -0.077478     0.036233        0.071751
# Tech_Oscar               0.021134     0.061414       -0.072842
# 3D_available_YES         0.004617     0.035491        0.017341
# Genre_Comedy             1.000000    -0.323621       -0.500192
# Genre_Drama             -0.323621     1.000000       -0.366563
# Genre_Thriller          -0.500192    -0.366563        1.000000

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["feature"] = df.columns
vif_data["VIF"] = [variance_inflation_factor(df.values, i) for i in range(len(df.columns))]

print(vif_data)
# Out:
#                 feature           VIF
# 0     Marketing expense      1.780520
# 1    Production expense     84.161266
# 2                Budget    156.545642
# 3          Movie_length     75.451196
# 4    Lead_ Actor_Rating  18792.020682
# 5   Lead_Actress_rating  22275.677790
# 6       Director_rating  19721.883831
# 7       Producer_rating   6036.205211
# 8         Critic_rating    110.094417
# 9         Trailer_views    107.510978
# 10           Time_taken     27.443002
# 11      Twitter_hastags      7.327894
# 12       Avg_age_actors     11.002353
# 13           Collection     19.329603
# 14           Tech_Oscar      2.434546
# 15     3D_available_YES      2.399414
# 16         Genre_Comedy      3.225451
# 17          Genre_Drama      2.415344
# 18       Genre_Thriller      3.614368

# %%
df.drop(['Lead_Actress_rating', 'Lead_ Actor_Rating',"Director_rating","Producer_rating","Critic_rating","Budget","Production expense"], axis=1,inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["feature"] = df.columns
vif_data["VIF"] = [variance_inflation_factor(df.values, i) for i in range(len(df.columns))]

print(vif_data)
# Out:
#               feature        VIF
# 0   Marketing expense   1.657714
# 1        Movie_length  21.660056
# 2       Trailer_views  50.859266
# 3          Time_taken  25.505459
# 4     Twitter_hastags   7.144121
# 5      Avg_age_actors  10.836196
# 6          Collection  15.045444
# 7          Tech_Oscar   2.366211
# 8    3D_available_YES   2.353437
# 9        Genre_Comedy   3.153053
# 10        Genre_Drama   2.355461
# 11     Genre_Thriller   3.555372

# %% [markdown]
# ### X-y split (Input-Output Split)

# %%
# Separating the output from the dataset

X = df.loc[:,df.columns!="Tech_Oscar"]
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
# Checking the first fove rows of the input columns

X.head()
# Out:
#    Marketing expense  Movie_length  Trailer_views  Time_taken  \
# 0            20.1264         138.7         527367      109.60
# 1            20.5462         152.4         494055      146.64
# 2            20.5458         134.6         547051      147.88
# 3            20.6474         119.3         516279      185.36
# 4            21.3810         127.7         531448      176.48
#
#    Twitter_hastags  Avg_age_actors  Collection  3D_available_YES  \
# 0          223.840              23       48000                 1
# 1          243.456              42       43200                 0
# 2         2022.400              38       69400                 0
# 3          225.344              45       66800                 1
# 4          225.792              55       72400                 0
#
#    Genre_Comedy  Genre_Drama  Genre_Thriller
# 0             0            0               1
# 1             0            1               0
# 2             1            0               0
# 3             0            1               0
# 4             0            1               0

# %%
# Checking the shape of the input dataset

X.shape
# Out:
# (506, 11)

# %%
# Creating output column

y = df["Tech_Oscar"]
type(y)
# Out:
# pandas.core.series.Series

# %%
# Checking teh First five rows of the output

y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: Tech_Oscar, dtype: int64

# %%
# Checking the number of rows and coliumns of the output

y.shape
# Out:
# (506,)

# %% [markdown]
# ### Test-Train Split

# %%
# Importing the tarin test split package

from sklearn.model_selection import train_test_split

# %%
# Separating the Training and testing Data

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3,random_state=0)

# %%
# Checking first five rows of input training dataset

X_train.head()
# Out:
#      Marketing expense  Movie_length  Trailer_views  Time_taken  \
# 141            52.5728         173.5         233100      199.76
# 272            22.2920         132.2         502420      169.76
# 135            31.1556         171.7         411162      157.24
# 298            21.2932          93.6         517172      189.00
# 122            21.8598         166.4         388265      178.20
#
#      Twitter_hastags  Avg_age_actors  Collection  3D_available_YES  \
# 141          242.304              43       28800                 1
# 272          263.904              40       48800                 1
# 135          222.896              37       36200                 1
# 298          263.600              48       45000                 0
# 122          203.280              51       41000                 1
#
#      Genre_Comedy  Genre_Drama  Genre_Thriller
# 141             1            0               0
# 272             0            0               1
# 135             0            0               1
# 298             0            1               0
# 122             1            0               0

# %%
# Checking the number of rows and columns of input training dataset

X_train.shape
# Out:
# (354, 11)

# %%
# Checking the number of rows and columns of input testing dataset

X_test.shape
# Out:
# (152, 11)

# %%
Algorithmns/Computer = Numbers

A- 1000 to 100000

B - 0 to 10

C 0 and 1
# Out:
#   File "C:\Users\ankit\AppData\Local\Temp/ipykernel_764/38483587.py", line 1
#     Algorithmns/Computer = Numbers
#     ^
# SyntaxError: cannot assign to operator

# %% [markdown]
# ### Rescaling the Data using Standardization

# %%
# Importing the standardscaler package for standardization

from sklearn.preprocessing import StandardScaler

# %%
# Applying the standardscaler to training data

sc = StandardScaler().fit(X_train)

# %%
# Transforming the training data into standard

X_train_std = sc.transform(X_train)

# %%
X_train_std
# Out:
# array([[-0.20735619,  1.10740225, -3.19049164, ...,  1.50923086,
#         -0.47871355, -0.76644892],
#        [-0.38886492, -0.36766106,  0.74554995, ..., -0.66258916,
#         -0.47871355,  1.30471839],
#        [-0.33573486,  1.04311378, -0.58816193, ..., -0.66258916,
#         -0.47871355,  1.30471839],
#        ...,
#        [-0.38450355,  0.48594701,  0.0489384 , ..., -0.66258916,
#         -0.47871355, -0.76644892],
#        [-0.37511786,  0.58952288, -1.11962692, ..., -0.66258916,
#         -0.47871355,  1.30471839],
#        [-0.38592298,  0.69667034, -0.52353555, ..., -0.66258916,
#         -0.47871355,  1.30471839]])

# %%
sc = StandardScaler().fit(X_test)

# %%
# Transforming the input testing data 

X_test_std = sc.transform(X_test)

# %%
X_test_std
# Out:
# array([[-0.45379523, -1.7758721 ,  0.52785202, ...,  1.49467139,
#         -0.5061604 , -0.72111026],
#        [ 0.55063352,  1.14170823,  0.11507065, ...,  1.49467139,
#         -0.5061604 , -0.72111026],
#        [-0.44864325,  0.873911  ,  0.08141111, ...,  1.49467139,
#         -0.5061604 , -0.72111026],
#        ...,
#        [ 1.38129558,  1.07475892, -2.55812273, ..., -0.66904338,
#         -0.5061604 , -0.72111026],
#        [-0.407137  ,  0.52506988,  1.33878017, ..., -0.66904338,
#         -0.5061604 ,  1.38675049],
#        [-0.45789292, -0.31355828,  0.74843251, ...,  1.49467139,
#         -0.5061604 , -0.72111026]])

# %% [markdown]
# ### Logistic Regression
#
# https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# %%
# Importing the logistic regression
from sklearn.linear_model import LogisticRegression

# %%
# Applying the SVM Classifier to training data

logreg = LogisticRegression()
logreg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ### Predict values using trained model

# %%
y_pred=logreg.predict(X_test)

# %% [markdown]
# ### Model Performance

# %%
# Importing accuracy-score and confusion_matrix pacakge

from sklearn.metrics import accuracy_score, confusion_matrix

# %%
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[46, 17],
#        [34, 55]], dtype=int64)

# %%
# Checking the accuracy Score
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6644736842105263

# %%
print("Precision:",metrics.precision_score(y_test, y_pred))
# Out:
# Precision: 0.7638888888888888

# %% [markdown]
# # naive bayes

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y1=model.predict(X_test)

# %%
print("Precision:",metrics.precision_score(y_test, y1))
# Out:
# Precision: 0.8333333333333334

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y1))
# Out:
# Accuracy: 0.5197368421052632

# %% [markdown]
# ### Grid Search

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
model.fit(X_train,y_train)

# %%
model.score(X_test,y_test)

# %%
model.score(X_train,y_train)

# %%
# Importing the Hyperparameter optimization Gridsearchcv pacakges

from sklearn.model_selection import GridSearchCV

# %%
# Setting the different hyperparamter value C 

params = {'C':(0.001,0.005,0.01,0.05, 0.1, 0.5, 1, 5, 10, 50,100,500,1000)}

# %%
# Creating objevt of SVC Classifier

clf_svm_l = svm.SVC(kernel='linear')

# %%
# Applying hyperparameter GridSearchCV 

svm_grid_lin = GridSearchCV(clf_svm_l, params, n_jobs=-1,
                            cv=10, verbose=1, scoring='accuracy')

# %%
# Applying training data to GridSearchCV

svm_grid_lin.fit(X_train_std, y_train)

# %%
# Checking the best parameter of SVM 
svm_grid_lin.best_params_

# %%
# Applying the best parameter value to classifier

linsvm_clf = svm_grid_lin.best_estimator_

# %%
# Checking the accurcay score on best parameter value

accuracy_score(y_test, linsvm_clf.predict(X_test_std))

# %% [markdown]
# ### Polynomial

# %%
# Applying SVC Classifier with Polynomial Kernel

clf_svm_p3 = svm.SVC(kernel='poly', degree=2, C=0.1)
clf_svm_p3.fit(X_train_std, y_train)

# %%
# predicting the training and testing data values

y_train_pred = clf_svm_p3.predict(X_train_std)
y_test_pred = clf_svm_p3.predict(X_test_std)

# %%
# Checking the acuuracy score

accuracy_score(y_test, y_test_pred)

# %%
# Checking the parameter values

clf_svm_p3.n_support_

# %% [markdown]
# ### Radial

# %%
# Applying SVC Classifier with rbf Kernel

clf_svm_r = svm.SVC(kernel='rbf', gamma=0.5, C=10)
clf_svm_r.fit(X_train_std, y_train)

# %%
# Predicting the training and testing data values

y_train_pred = clf_svm_r.predict(X_train_std)
y_test_pred = clf_svm_r.predict(X_test_std)

# %%
# Checking the accurcay score

accuracy_score(y_test, y_test_pred)

# %%
# Checking the Parameter values

clf_svm_r.n_support_

# %% [markdown]
# ### Radial Grid

# %%
# Applying the different Hyperparameter values of C and gamma

params = {'C':(0.01,0.05, 0.1, 0.5, 1, 5, 10, 50), 
          'gamma':(0.001, 0.01, 0.1, 0.5, 1)}

# %%
# Applying SVC Classifier with rbf kernel

clf_svm_r = svm.SVC(kernel='rbf')

# %%
# creating objevt with the Hyperparameter GridSearchCV with different values

svm_grid_rad = GridSearchCV(clf_svm_r, params, n_jobs=-1,
                            cv=3, verbose=1, scoring='accuracy')

# %%
# Applying the hyperparameter to training and testing data

svm_grid_rad.fit(X_train_std, y_train)

# %%
# Checking best values of Hyperparamters

svm_grid_rad.best_params_

# %%
# Checking the best estimator

radsvm_clf = svm_grid_rad.best_estimator_

# %%
# Checking the accuracy score with best Hyperparamter values

accuracy_score(y_test, radsvm_clf.predict(X_test_std))
